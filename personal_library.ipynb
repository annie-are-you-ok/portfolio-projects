# %% [markdown]
# <a href="https://colab.research.google.com/github/annie-are-you-ok/portfolio-projects/blob/main/personal_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/annies_library.csv')
df.head()
# Out:
#    Unnamed: 0     Format                           Title      Series  \
# 0           1  Paperback                         Sabriel  Abhorsen 1
# 1           2  Paperback     A Court of Thorns and Roses    ACOTAR 1
# 2           3  Paperback        A Court of Mist and Fury    ACOTAR 2
# 3           4  Paperback       A Court of Wings and Ruin    ACOTAR 3
# 4           5  Paperback  A Court of Frost and Starlight  ACOTAR 3.5
#
#          Author     Type    Genre Read?  Year Finished  Rating  Date Added  \
# 0     Garth Nix  Fiction  Fantasy    no            NaN     NaN  12/07/2023
# 1  Sarah J Maas  Fiction  Fantasy   yes         2021.0     5.0  01/12/2020
# 2  Sarah J Maas  Fiction  Fantasy   yes         2021.0     5.0  01/01/2021
# 3  Sarah J Maas  Fiction  Fantasy   yes         2021.0     5.0  01/01/2021
# 4  Sarah J Maas  Fiction  Fantasy   yes         2021.0     3.5  01/01/2021
#
#   Notes
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     278 non-null    int64
#  1   Format         278 non-null    object
#  2   Title          278 non-null    object
#  3   Series         108 non-null    object
#  4   Author         277 non-null    object
#  5   Type           278 non-null    object
#  6   Genre          277 non-null    object
#  7   Read?          278 non-null    object
#  8   Year Finished  122 non-null    float64
#  9   Rating         118 non-null    float64
#  10  Date Added     278 non-null    object
#  11  Notes          62 non-null     object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 26.2+ KB

# %% [markdown]
# - delete column 1
# - delete dnf's
# - convert to int: 'Year Finished', 'Rating', 'Date Added'
# -
